# %%
#Convolutional Filter

#Import Libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage import exposure

# %%
#Convolution
def convolve2d(image, kernel):
    
    output = np.zeros_like(image) 
    kernel = np.flipud(np.fliplr(kernel))
    padding = np.zeros((image.shape[0] + 2, image.shape[1] + 2))
    image = padding[1:-1, 1:-1]
    
     # Loop over every pixel of the image
    for x in range(image.shape[1]):    
        for y in range(image.shape[0]):
             output[y,x]=(kernel*padding[y:y+3,x:x+3]).sum() # element-wise multiplication of the kernel and the image  
    return output


#Load image
img = cv2.imread('Downloads/conv img.jpg')

plt.imshow(img)
img.shape[:3]
# Out:
# (897, 1168, 3)

# %%
# Convert the image to gray_img = cv2.cvscale 

gray=cv2.cvtColor(img, cv2. COLOR_RGB2GRAY)
plt.imshow(gray)

# %%
# Adjust the contrast of the image using applying Histogram Equalization 
image_equalized = exposure.equalize_adapthist(img/np.max(np.abs(img)), clip_limit=0.03)
plt.imshow(image_equalized, cmap=plt.cm.gray)
plt.axis('off')
plt.show()
# Out:
# C:\Users\durga\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# Histogram equalization after Filter
from skimage import exposure

kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
image_sharpen = cv2.filter2D(img,-1,kernel)
print ('\n First 5 columns and rows of the image_sharpen matrix: \n', image_sharpen[:5,:5]*255)
# Adjust the contrast of the filtered image by applying Histogram Equalization 
image_sharpen_equalized = exposure.equalize_adapthist(image_sharpen/np.max(np.abs(image_sharpen)), clip_limit=0.03)
plt.imshow(image_sharpen_equalized, cmap=plt.cm.gray)
plt.axis('off')
plt.show()
# Out:
#  First 5 columns and rows of the image_sharpen matrix:
#  [[[162 162 162]
#   [171 171 171]
#   [187 187 187]
#   [189 189 189]
#   [180 180 180]]
#
#  [[155 155 155]
#   [173 173 173]
#   [155 155 155]
#   [169 169 169]
#   [170 170 170]]
#
#  [[187 187 187]
#   [191 191 191]
#   [164 164 164]
#   [168 168 168]
#   [182 182 182]]
#
#  [[167 167 167]
#   [166 166 166]
#   [162 162 162]
#   [164 164 164]
#   [181 181 181]]
#
#  [[174 174 174]
#   [151 151 151]
#   [177 177 177]
#   [165 165 165]
#   [179 179 179]]]
# C:\Users\durga\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))

# %%
kernel = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])

Edge_img = cv2.filter2D(img,-1,kernel)
print ('\n First 5 columns and rows of the image_sharpen matrix: \n', image_sharpen[:5,:5]*255)

edges_equalized = exposure.equalize_adapthist(Edge_img/np.max(np.abs(Edge_img)), clip_limit=0.03)
plt.imshow(edges_equalized, cmap=plt.cm.gray)    # plot the edges_clipped
plt.axis('off')
plt.show()
# Out:
#  First 5 columns and rows of the image_sharpen matrix:
#  [[[162 162 162]
#   [171 171 171]
#   [187 187 187]
#   [189 189 189]
#   [180 180 180]]
#
#  [[155 155 155]
#   [173 173 173]
#   [155 155 155]
#   [169 169 169]
#   [170 170 170]]
#
#  [[187 187 187]
#   [191 191 191]
#   [164 164 164]
#   [168 168 168]
#   [182 182 182]]
#
#  [[167 167 167]
#   [166 166 166]
#   [162 162 162]
#   [164 164 164]
#   [181 181 181]]
#
#  [[174 174 174]
#   [151 151 151]
#   [177 177 177]
#   [165 165 165]
#   [179 179 179]]]
# C:\Users\durga\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
